# %% [markdown]
# # APPROCHE GLOBALE

# %% [markdown]
# ## NOTRE CLIENT

# %% [markdown]
# Un jeune label qui cherche à organiser un festival pour promouvoir ses articles, gagner en visibilité.
#
# À quoi sert un label Musique :
# Un label musical est une entreprise de production d'artistes musicaux. Elle a pour but de trouver des talents, des artistes qu'elle pourra accompagner dans le processus d'enregistrement, de commercialisation et dans le développement de leur carrière.
#
# Le label oriente les artistes vers la production de disques, l’organisation de représentation, la phase de promotion, ou encore la mise à disposition des titres sur les plateformes de streaming légales. Le label musical se rémunère sur les ventes générées par la musique produite, tout en reversant une rémunération aux artistes selon les modalités fixées dans un contrat.

# %% [markdown]
# ## LA PROBLEMATIQUE

# %% [markdown]
# ENJEUX :
# 1) Se rémunérer sur l'évenement
# 2) Gagner en visibilité avec de gros artistes
# 3) Faire découvrir de nouveaux talents
# 4) Pour le festival : trouver un équilibre entre tête d'affiche et petits artistes découverte (detecter de nouveaux talents).

# %% [markdown]
# OBJECTIF :
# 1) Présentater au label un état des lieux du marché musical actuel
# 2) Faire un état des lieux de ses 10 artistes actuels => voir ceux qu'il faut pousser au festival
# 3) Faire une recommandation de programmation d'artistes pour le festival sur 2 jours (stratégie associée)
#     - classifier les artistes tête d'affiche
#     - classifier les artistes niches

# %% [markdown]
# METHODE :
#
# - Définir un sample du DF pour le label (choisir des articles pour notre label arbitrairement).
# - Classifier les articles du label dans le mapping
# - Faire une recommandation de programmation : slide de nos connaissances actuelles

# %% [markdown]
# ![image.png](attachment:4459a26f-b282-4c54-b09b-b99551968ef1.png)

# %% [markdown]
# OUTILS : python, streamlit, jupyterlab
#
# RENDU CLIENT (label) SUR STREAMLIT :
#
# 1) RESUME DU PROJET : DEMANDE CLIENT, PROBLEMATIQUE, ENJEUX, PRESENTATION DE L'EQUIPE, SOMMAIRE
#
# 2) PRESENTATION DU DATASETS, LES DONNES TECHNIQUES : tables
# 3) ANALYST DU MARCHE : ETAT DES LIEUX DU MARCHE
# 4) VOS ARTISTES : ceux à pousser au festival  + débauchage + partenariats
# 5) NOTRE RECOMMANDATION DE PROGRAMMATION

# %% [markdown]
# ## CHOIX DU DATASET

# %% [markdown]
# Spotify : extrait quotidien du top 200 des morceaux les plus streamés (charts)
# https://www.kaggle.com/datasets/dhruvildave/spotify-charts
#
# Spotify : attributs de 1,2M de chansons (feature) : analyse de marché
# https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs
#
# Spotify : attributs de 100k de chansons avec genre musical (feature)
# https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset
#
# Spotify & Youtube : machine learning
# https://www.kaggle.com/datasets/salvatorerastelli/spotify-and-youtube

# %% [markdown]
# ## KPI A ANALYSER

# %% [markdown]
# KPI ANALYSE DE MARCHE :
#
# TOP 200 :
# - Région : global et France
# - Dates : 2017 à 2021
#
# - Le top 5 des genres (uniques) de plus représentés
# - Tracker les genres avec le plus de danceability + energy
#
# - Données statistiques : danceability + energy
#
# - Le top 3 artistes (uniques) par genre
# - Popularité de l'artiste : le plus streamé,
# - Analyser les quartils, moyennes nb de stream
#
# données you tube additionnelles : nb de vues, likes, comments
#
# ETOILES :
# - stream > x ,
# - vues > y,
# - capable de rester dans le top 20 pendant 4 jours, (moyenne des jours où le nombre de stream est > à X)
#
#
# PEPITES :
# - Les 10 plus grosses évolutions en nombre de streams  (avec un nombre de stream minimal tout de même)

# %% [markdown]
# KPI QUELS ARTISTES POUSSER EN LIVE :
#
# Montrer une corrélation entre l'écoute spotify et les vues you tube => pour montrer le potentiel en concert
#
#
# CRITERES EN CONCERT :
# danceability, ...

# %% [markdown]
# # DATASETS SELECTIONNES

# %% [markdown]
# ## TOP 200
# Extrait quotidien du top 200 des morceaux les plus streamés (charts)

# %%
import pandas as pd
df_top_200 = pd.read_csv("/Users/camillemagnette/Documents/FORMATION DATA ANALYST/COURS DATA ANALYST/HACKATHON MUSIQUE/DATASETS/charts.csv", sep = ",")
df_top_200.info()
# df = pd.read_csv('C:\\Users\\aissa\\Downloads\\archive\charts.csv', header=0, sep=',', quotechar='"', low_memory= False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26173514 entries, 0 to 26173513
# Data columns (total 9 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   title    object
#  1   rank     int64
#  2   date     object
#  3   artist   object
#  4   url      object
#  5   region   object
#  6   chart    object
#  7   trend    object
#  8   streams  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.8+ GB

# %%
df_top_200.shape
# Out:
# (26173514, 9)

# %%
df_top_200
# Out:
#                                   title  rank        date  \
# 0               Chantaje (feat. Maluma)     1  2017-01-01
# 1           Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2            Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                Safari     4  2017-01-01
# 4                           Shaky Shaky     5  2017-01-01
# ...                                 ...   ...         ...
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                                          artist  \
# 0                                       Shakira
# 1                                  Ricky Martin
# 2                                          CNCO
# 3         J Balvin, Pharrell Williams, BIA, Sky
# ...

# %%
# Vérification des doublons
df_top_200.duplicated().sum()
# Out:
# 0

# %%
# Vérification des valeurs manquantes
df_top_200.isnull().sum()
# Out:
# title           11
# rank             0
# date             0
# artist          18
# url              0
# region           0
# chart            0
# trend            0
# streams    5851610
# dtype: int64

# %%
# Supprimer les lignes avec des valeurs nulles dans les colonnes artist et title 
df_top_200.dropna(subset=['artist', 'title'], inplace=True)

# %%
# Transforer la colonne date en format date
df_top_200['date'] = pd.to_datetime(df_top_200['date'])

# %%
# Remplacer les valeurs manquantes de la colonne streams par 0 
df_top_200['streams'].fillna('0', inplace=True)

# %%
# Supprimer la colonne url 
df_top_200.drop('url', axis=1, inplace=True)

# %%
df_top_200
# Out:
#                                   title  rank       date  \
# 0               Chantaje (feat. Maluma)     1 2017-01-01
# 1           Vente Pa' Ca (feat. Maluma)     2 2017-01-01
# 2            Reggaetón Lento (Bailemos)     3 2017-01-01
# 3                                Safari     4 2017-01-01
# 4                           Shaky Shaky     5 2017-01-01
# ...                                 ...   ...        ...
# 26173509                            BYE    46 2021-07-31
# 26173510                        Pillars    47 2021-07-31
# 26173511                   Gái Độc Thân    48 2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49 2021-07-31
# 26173513                Letter to Jarad    50 2021-07-31
#
#                                          artist     region    chart  \
# 0                                       Shakira  Argentina   top200
# 1                                  Ricky Martin  Argentina   top200
# 2                                          CNCO  Argentina   top200
# ...

# %%
date_max = df_top_200['date'].max()
date_min = df_top_200['date'].min()
print("Date maximale :", date_max)
print("Date minimale :", date_min)
# Out:
# Date maximale : 2021-12-31 00:00:00
# Date minimale : 2017-01-01 00:00:00

# %%
# Afficher toutes les valeurs uniques de la colonne region 
tendances_uniques = df_top_200['region'].unique()
print(tendances_uniques)
# Out:
# ['Argentina' 'Australia' 'Brazil' 'Austria' 'Belgium' 'Colombia' 'Bolivia'
#  'Denmark' 'Bulgaria' 'Canada' 'Chile' 'Costa Rica' 'Czech Republic'
#  'Finland' 'Dominican Republic' 'Ecuador' 'El Salvador' 'Estonia' 'France'
#  'Germany' 'Global' 'Greece' 'Guatemala' 'Honduras' 'Hong Kong' 'Hungary'
#  'Iceland' 'Indonesia' 'Ireland' 'Italy' 'Japan' 'Latvia' 'Lithuania'
#  'Malaysia' 'Luxembourg' 'Mexico' 'Netherlands' 'New Zealand' 'Nicaragua'
#  'Norway' 'Panama' 'Paraguay' 'Peru' 'Philippines' 'Poland' 'Portugal'
#  'Singapore' 'Spain' 'Slovakia' 'Sweden' 'Taiwan' 'Switzerland' 'Turkey'
#  'United Kingdom' 'United States' 'Uruguay' 'Thailand' 'Andorra' 'Romania'
#  'Vietnam' 'Egypt' 'India' 'Israel' 'Morocco' 'Saudi Arabia'
#  'South Africa' 'United Arab Emirates' 'Russia' 'Ukraine' 'South Korea']

# %%
# Filtrer la colonne region sur : global et france uniquement 
df_top_200 = df_top_200[df_top_200['region'].isin(['Global', 'France'])]

# %%
# Filtrer la colonne chart sur : top200 uniquement 
df_top_200 = df_top_200[df_top_200['chart'] == 'top200']

# %%
# Supprimer les index
df_top_200.reset_index(drop=True, inplace=True)

# %%
df_top_200
# Out:
#                                         title  rank       date  \
# 0                                   One Dance     1 2017-01-01
# 1                                     Starboy     2 2017-01-01
# 2                                   24K Magic     3 2017-01-01
# 3                                      My Way     4 2017-01-01
# 4                             Mauvaise graine     5 2017-01-01
# ...                                       ...   ...        ...
# 720567                                    San   178 2018-01-31
# 720568               La pluie (feat. Stromae)   179 2018-01-31
# 720569  Say Something (feat. Chris Stapleton)   180 2018-01-31
# 720570                          What About Us   181 2018-01-31
# 720571                             This Is Me   182 2018-01-31
#
#                                              artist  region   chart  \
# 0                               Drake, WizKid, Kyla  France  top200
# 1                             The Weeknd, Daft Punk  France  top200
# ...

# %%
# Afficher le top 5 des lignes les plus streamées
top_5_streams = df_top_200.nlargest(15, 'streams')
top_5_streams
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/0n/nghj_5ys5zb8mhkhc6y033th0000gn/T/ipykernel_23888/1532746956.py in <module>
#       1 # Afficher le top 5 des lignes les plus streamées
# ----> 2 top_5_streams = df_top_200.nlargest(15, 'streams')
#       3 top_5_streams
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    6697         Brunei      434000    12128      BN
#    6698         """
# -> 6699         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    6700
#    6701     def nsmallest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in nlargest(self)
#    1135     @final
#    1136     def nlargest(self):
# -> 1137         return self.compute("nlargest")
#    1138
# ...

# %%
top_3_artists = df_top_200['artist'].value_counts().head(3)
top_3_artists
# Out:
# Ed Sheeran       13242
# Ninho            12838
# Billie Eilish     9011
# Name: artist, dtype: int64

# %% [markdown]
# ## Attributs de 1,2M de chansons (feature)

# %%
import pandas as pd
df_feature = pd.read_csv("/Users/camillemagnette/Documents/FORMATION DATA ANALYST/COURS DATA ANALYST/HACKATHON MUSIQUE/DATASETS/tracks_features.csv", sep = ",")
df_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204025 entries, 0 to 1204024
# Data columns (total 24 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   id                1204025 non-null  object
#  1   name              1204025 non-null  object
#  2   album             1204025 non-null  object
#  3   album_id          1204025 non-null  object
#  4   artists           1204025 non-null  object
#  5   artist_ids        1204025 non-null  object
#  6   track_number      1204025 non-null  int64
#  7   disc_number       1204025 non-null  int64
#  8   explicit          1204025 non-null  bool
#  9   danceability      1204025 non-null  float64
#  10  energy            1204025 non-null  float64
#  11  key               1204025 non-null  int64
#  12  loudness          1204025 non-null  float64
#  13  mode              1204025 non-null  int64
#  14  speechiness       1204025 non-null  float64
# ...

# %%
df_feature.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
colonnes = df_feature.columns
print(colonnes)
# Out:
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'],
#       dtype='object')

# %%
df_feature.duplicated().sum()  # Vérification des doublons
# Out:
# 0

# %%
df_feature.isnull().sum()  # Vérification des valeurs manquantes
# Out:
# id                  0
# name                0
# album               0
# album_id            0
# artists             0
# artist_ids          0
# track_number        0
# disc_number         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# year                0
# release_date        0
# dtype: int64

# %% [markdown]
# ## 3ème : attributs de 100k de chansons avec genre musical (feature)

# %%
import pandas as pd
df_dataset = pd.read_csv("/Users/camillemagnette/Documents/FORMATION DATA ANALYST/COURS DATA ANALYST/HACKATHON MUSIQUE/DATASETS/dataset.csv", sep = ",")
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df_dataset
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df_dataset["track_genre"].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...
